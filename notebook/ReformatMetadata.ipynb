# %%
import pandas as pd
import numpy as np
import uuid

# %%
df = pd.read_excel("meta_final_transpose.xlsx")
df['analysis/data type'] = 'metagenomics'

# %%
sample_name = list()
for i, (idx, row) in enumerate(df[['Structured comment name', 'experimental_factor', 'host_common_name', 'chem_administration', 'perturbation']].iterrows()):
    sname = ""
    if row['host_common_name'] == 'Canine':
        sname = "Canine with " + row['perturbation']
        chem_adm = row['chem_administration']
        if chem_adm == 'none' or chem_adm is None or chem_adm is np.nan:
            sname = f'{sname} - no treatment'
        else:
            sname = f'{sname} - treatment with ' + row['chem_administration']
    else:
        sname = 'Mouse - ' + row['experimental_factor']
    sname += f' ({row["Structured comment name"]})'
    sample_name.append(sname)
sample_name
# Out:
# ['Canine with Bacteremia, urinary tract infection - treatment with Prednisone, Ondansetron (HS25_11)',
#  'Canine with Bacteremia, urinary tract infection - treatment with Prednisone, Ondansetron, Enrofloxacin (HS25_12)',
#  'Canine with Pyoderma - treatment with Cytopoint (HS25_21)',
#  'Canine with Pyoderma - treatment with Cytopoint, Cephalexin (HS25_22)',
#  'Canine with Cholangiohepatitis - treatment with Prednisolone, Omperazole (HS25_31)',
#  'Canine with Cholangiohepatitis - treatment with Prednisolone, Omperazole, Enrofloxacin, Metronidazole (HS25_32)',
#  'Canine with urinary tract infection - treatment with Cyclosporine, Denamarin, Ursodiol, D-penicillamine, Maropitant (HS25_41)',
#  'Canine with urinary tract infection - treatment with Cyclosporine, Denamarin, Ursodiol, D-penicillamine, Maropitant, Clavamox (HS25_42)',
#  'Canine with Aspiration pneumonia - treatment with Prednisone, Ondansetron (HS25_51)',
#  'Canine with Aspiration pneumonia - treatment with Prednisone, Ondansetron, Clindamycin (HS25_52)',
#  'Canine with Digit amputation - treatment with Pimobendan, Benazapril, Spironolactone, Prednisolone, Vitamin B12 (HS25_61)',
#  'Canine with Digit amputation - treatment with Pimobendan, Benazapril, Spironolactone, Prednisolone, Vitamin B12, Clavamox (HS25_62)',
#  'Canine with Pyoderma - treatment with Carprofen (HS25_71)',
#  'Canine with Pyoderma - treatment with Carprofen, Simplicef (HS25_72)',
#  'Canine with Wound - treatment with Carprofen, Trazadone (HS25_101)',
#  'Canine with Wound - treatment with Carprofen, Trazadone, Clavamox (HS25_102)',
#  'Canine with Aspiration pneumonia - treatment with Pantoprazole, Maropitant (HS25_111)',
#  'Canine with Aspiration pneumonia - treatment with Pantoprazole, Maropitant, Unasyn (HS25_112)',
#  'Canine with infectious respiratory disease - treatment with Prednisone, Theophylline (HS25_121)',
#  'Canine with infectious respiratory disease - treatment with Prednisone, Theophylline, Doxycycline (HS25_122)',
#  'Canine with Aspiration pneumonia - no treatment (HS25_151)',
#  'Canine with Aspiration pneumonia - treatment with Clavamox (HS25_152)',
#  'Canine with Cholangiohepatitis - treatment with Ursodiol, Denamarin, Levetiracetam, Ondansetron, Gabapentin (HS25_171)',
#  'Canine with Cholangiohepatitis - treatment with Ursodiol, Denamarin, Levetiracetam, Ondansetron, Gabapentin, Clavamox (HS25_172)',
#  'Canine with dental procedure - no treatment (HS25_COCO1)',
#  'Canine with dental procedure - treatment with Clindamycin (HS25_COCO2)',
#  'Canine with anal sac abscess - no treatment (HS25_LAYLA1)',
#  'Canine with anal sac abscess - treatment with Clindamycin (HS25_LAYLA2)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_11)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_12)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_13)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_21)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_22)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_23)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_31)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_32)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_33)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_41)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_42)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS159_43)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_11)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_12)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_13)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_21)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_22)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_23)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_31)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_32)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_41)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_42)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_43)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_51)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_52)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_61)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_62)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_63)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_71)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_72)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_81)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_82)',
#  'Mouse - antibiotic treatment, 5-ASA treatment, C17 treatment (HS177_83)']

# %%
df['sample name'] = sample_name

# %%
df.iloc[:, 0] = ['UUID:' + str(uuid.uuid3(uuid.NAMESPACE_X500, i)) for i in df.iloc[:, 0]]

# %%
new_cols = list(df.columns)
keep_cols = [0, len(df.columns)-1]
new_cols[0] = "globally unique ID"

col_keys = set(new_cols)
col_keys.remove('sample name')

keymap = {
    'chem_administration': 'chemical administration',
    'env_medium': 'environmental medium',
    'perturbation': 'perturbation',
    'collection_date': 'collection date',
    'experimental_factor': 'experimental factor',
    'env_local_scale': 'local environmental context',
    'env_broad_scale': 'broad-scale environmental context',
    'env_package': 'environmental package',
    'env_medium': 'environmental medium',
    'lat_lon': 'geographic location (latitude and longitude)',
    'samp_store_temp': 'sample storage temperature',
    
}

unchanged_keys = ['perturbation', 'gravidity', 'analysis/data type']
for k in unchanged_keys:
    keymap[k] = k


for i, key in enumerate(new_cols):
    updated = False
    if key[:4] == 'host':
        new_cols[i] = key.replace('_', ' ')
        updated = True
    elif key in keymap:
        new_cols[i] = keymap[key]
        updated = True
        
    if updated:
        col_keys.remove(key)
        keep_cols.append(i)
    
col_keys
# Out:
# {'adapters',
#  'chimera_check',
#  'geo_loc_name',
#  'globally unique ID',
#  'investigation_type',
#  'lib_layout',
#  'lib_reads_seqd',
#  'lib_screen',
#  'lib_size',
#  'mid',
#  'nucl_acid_amp',
#  'nucl_acid_ext',
#  'pcr_cond',
#  'pcr_primers',
#  'project_name',
#  'samp_collect_device',
#  'samp_mat_process',
#  'seq_meth',
#  'submitted_to_insdc',
#  'target_gene',
#  'target_subfragment',
#  'tax_class'}

# %%
new_df = df.iloc[:, keep_cols]
new_df.columns = np.array(new_cols)[keep_cols]
new_df
# Out:
#                            globally unique ID  \
# 0   UUID:67847769-4444-37f0-a011-f43daf6485aa
# 1   UUID:ee6be1ee-7841-3407-b560-dc09cb0cd3f4
# 2   UUID:b0fa9757-a9db-33a6-aefa-f7765a11e5d4
# 3   UUID:1a4182b1-f94f-3a98-874e-624d64998b26
# 4   UUID:55951206-45ed-31d2-8c03-6b82894802c3
# ..                                        ...
# 56  UUID:64d0771b-ebdc-3c83-9850-62eab9881b8d
# 57  UUID:e4dd1833-08a8-33de-800a-f4e461da9953
# 58  UUID:40867b05-5f44-3a94-ae0f-cf4d577f0612
# 59  UUID:d285264e-6d15-34fd-a05e-c4655e44e795
# 60  UUID:2249cd3a-9440-3a3e-9686-c28df83c1482
#
#                                           sample name  \
# 0   Canine with Bacteremia, urinary tract infectio...
# 1   Canine with Bacteremia, urinary tract infectio...
# 2   Canine with Pyoderma - treatment with Cytopoin...
# 3   Canine with Pyoderma - treatment with Cytopoin...
# 4   Canine with Cholangiohepatitis - treatment wit...
# ..                                                ...
# 56  Mouse - antibiotic treatment, 5-ASA treatment,...
# 57  Mouse - antibiotic treatment, 5-ASA treatment,...
# 58  Mouse - antibiotic treatment, 5-ASA treatment,...
# 59  Mouse - antibiotic treatment, 5-ASA treatment,...
# 60  Mouse - antibiotic treatment, 5-ASA treatment,...
#
#                                   experimental factor  \
# 0                                antibiotic treatment
# 1                                antibiotic treatment
# 2                                antibiotic treatment
# 3                                antibiotic treatment
# 4                                antibiotic treatment
# ..                                                ...
# 56  antibiotic treatment, 5-ASA treatment, C17 tre...
# 57  antibiotic treatment, 5-ASA treatment, C17 tre...
# 58  antibiotic treatment, 5-ASA treatment, C17 tre...
# 59  antibiotic treatment, 5-ASA treatment, C17 tre...
# 60  antibiotic treatment, 5-ASA treatment, C17 tre...
#
#    geographic location (latitude and longitude) collection date  \
# 0                       38.5382∞ N, 121.7617∞ W      2019-09-18
# 1                       38.5382∞ N, 121.7617∞ W      2019-09-20
# 2                       38.5382∞ N, 121.7617∞ W      2019-10-02
# 3                       38.5382∞ N, 121.7617∞ W      2019-10-22
# 4                       38.5382∞ N, 121.7617∞ W      2019-10-07
# ..                                          ...             ...
# 56                      38.5382∞ N, 121.7617∞ W      2021-11-05
# 57                      38.5382∞ N, 121.7617∞ W      2021-11-05
# 58                      38.5382∞ N, 121.7617∞ W      2021-11-05
# 59                      38.5382∞ N, 121.7617∞ W      2021-11-05
# 60                      38.5382∞ N, 121.7617∞ W      2021-11-05
#
#                 broad-scale environmental context local environmental context  \
# 0   Animal-associated environment [ENVO:01001002]                   dog feces
# 1   Animal-associated environment [ENVO:01001002]                   dog feces
# 2   Animal-associated environment [ENVO:01001002]                   dog feces
# 3   Animal-associated environment [ENVO:01001002]                   dog feces
# 4   Animal-associated environment [ENVO:01001002]                   dog feces
# ..                                            ...                         ...
# 56  Animal-associated environment [ENVO:01001002]        mouse cecal contents
# 57  Animal-associated environment [ENVO:01001002]        mouse cecal contents
# 58  Animal-associated environment [ENVO:01001002]        mouse cecal contents
# 59  Animal-associated environment [ENVO:01001002]        mouse cecal contents
# 60  Animal-associated environment [ENVO:01001002]        mouse cecal contents
#
#     environmental medium environmental package host common name  ...  \
# 0              dog feces       Host-associated           Canine  ...
# 1              dog feces       Host-associated           Canine  ...
# 2              dog feces       Host-associated           Canine  ...
# 3              dog feces       Host-associated           Canine  ...
# 4              dog feces       Host-associated           Canine  ...
# ..                   ...                   ...              ...  ...
# 56  mouse cecal contents       Host-associated            Mouse  ...
# 57  mouse cecal contents       Host-associated            Mouse  ...
# 58  mouse cecal contents       Host-associated            Mouse  ...
# 59  mouse cecal contents       Host-associated            Mouse  ...
# 60  mouse cecal contents       Host-associated            Mouse  ...
#
#                   chemical administration       host body habitat  \
# 0                 Prednisone, Ondansetron  gastrointestinal tract
# 1   Prednisone, Ondansetron, Enrofloxacin  gastrointestinal tract
# 2                               Cytopoint  gastrointestinal tract
# 3                   Cytopoint, Cephalexin  gastrointestinal tract
# 4                Prednisolone, Omperazole  gastrointestinal tract
# ..                                    ...                     ...
# 56                                  5-ASA  gastrointestinal tract
# 57                                  5-ASA  gastrointestinal tract
# 58                                   none  gastrointestinal tract
# 59                                   none  gastrointestinal tract
# 60                                   none  gastrointestinal tract
#
#                       host body site       host body product  \
# 0   large intestine [UBERON:0000059]  Feces [UBERON:0001988]
# 1   large intestine [UBERON:0000059]  Feces [UBERON:0001988]
# 2   large intestine [UBERON:0000059]  Feces [UBERON:0001988]
# 3   large intestine [UBERON:0000059]  Feces [UBERON:0001988]
# 4   large intestine [UBERON:0000059]  Feces [UBERON:0001988]
# ..                               ...                     ...
# 56                             cecum          cecal contents
# 57                             cecum          cecal contents
# 58                             cecum          cecal contents
# 59                             cecum          cecal contents
# 60                             cecum          cecal contents
#
#                                             host diet     host genotype  \
# 0                                 Royal Canin low fat  Golden retreiver
# 1                                 Royal Canin low fat  Golden retreiver
# 2                           Ultamino + proplan canned    French bulldog
# 3                           Ultamino + proplan canned    French bulldog
# 4   Nutrition formulated diet with tilapia and swe...   Norwich terrier
# ..                                                ...               ...
# 56              Teklad Diet #TD110675 low fat control     Swiss Webster
# 57              Teklad Diet #TD110675 low fat control     Swiss Webster
# 58              Teklad Diet #TD110675 low fat control     Swiss Webster
# 59              Teklad Diet #TD110675 low fat control     Swiss Webster
# 60                      Teklad Diet #TD06415 high fat     Swiss Webster
#
#    gravidity                         perturbation sample storage temperature  \
# 0         no  Bacteremia, urinary tract infection         -20 degree celsius
# 1         no  Bacteremia, urinary tract infection         -20 degree celsius
# 2         no                             Pyoderma         -20 degree celsius
# 3         no                             Pyoderma         -20 degree celsius
# 4         no                   Cholangiohepatitis         -20 degree celsius
# ..       ...                                  ...                        ...
# 56        no               antibiotic-treated FMT         -20 degree celsius
# 57        no               antibiotic-treated FMT         -20 degree celsius
# 58        no          antibiotic-treated FMT, FMT         -20 degree celsius
# 59        no          antibiotic-treated FMT, FMT         -20 degree celsius
# 60        no          antibiotic-treated FMT, FMT         -20 degree celsius
#
#    analysis/data type
# 0        metagenomics
# 1        metagenomics
# 2        metagenomics
# 3        metagenomics
# 4        metagenomics
# ..                ...
# 56       metagenomics
# 57       metagenomics
# 58       metagenomics
# 59       metagenomics
# 60       metagenomics
#
# [61 rows x 25 columns]

# %%
tmpl_df = pd.read_excel('nmdc_sample_export.xlsx')
tmpl_df
# Out:
# Empty DataFrame
# Columns: [sample name, globally unique ID, analysis/data type, environmental package, sample linkage, broad-scale environmental context, local environmental context, environmental medium, ecosystem, ecosystem_category, ecosystem_type, ecosystem_subtype, specific_ecosystem, experimental factor, horizon method, miscellaneous parameter, oxygenation status of sample, temperature, salinity, collection date, geographic location (country and/or sea,region), geographic location (latitude and longitude), elevation, meters, sample storage temperature, depth, meters, sample material processing, sample collection device, sample collection method, chemical administration, amount or size of sample collected, relationship to oxygen, altitude, organism count, perturbation, sample storage location, ancestral data, biological status, genetic modification, host age, host common name, host dry mass, host genotype, host height, host length, host life stage, host phenotype, host subspecific genetic lineage, observed host symbionts, host taxid, host total mass, sample capture status, sample disease stage, size fraction selected, host blood pressure diastolic, host blood pressure systolic, gravidity, host body habitat, host body product, host body site, host body temperature, host color, host diet, host family relationship, host growth conditions, host last meal, host sex, host shape, host subject id, host substrate, sample storage duration]
# Index: []
#
# [0 rows x 70 columns]

# %%
for k in tmpl_df.columns:
    if k in new_df:
        tmpl_df[k] = new_df[k]
tmpl_df["collection date"] = tmpl_df["collection date"].dt.strftime("%Y-%m-%d")

# %%
envo_feces = "feces material [ENVO:00002003]"
for col in ("environmental medium", "local environmental context"):
    tmpl_df[col][tmpl_df[col] == 'dog feces'] = envo_feces
    tmpl_df[col][tmpl_df[col] == 'mouse cecal contents'] = 'mouse cecal contents [FMA:14541]'
# Out:
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1666323989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df[col][tmpl_df[col] == 'dog feces'] = envo_feces
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1666323989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df[col][tmpl_df[col] == 'mouse cecal contents'] = 'mouse cecal contents [FMA:14541]'
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1666323989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df[col][tmpl_df[col] == 'dog feces'] = envo_feces
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1666323989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df[col][tmpl_df[col] == 'mouse cecal contents'] = 'mouse cecal contents [FMA:14541]'

# %%
tmpl_df['host body site'][tmpl_df['host body site'] == 'cecum'] = 'cecum [UBERON:0001153]'
tmpl_df['host body product'][tmpl_df['host body product'] == 'cecal contents'] = 'cecal contents [FMA:14541]'
# Out:
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1200722079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df['host body site'][tmpl_df['host body site'] == 'cecum'] = 'cecum [UBERON:0001153]'
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/1200722079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df['host body product'][tmpl_df['host body product'] == 'cecal contents'] = 'cecal contents [FMA:14541]'

# %%
tmpl_df['host sex'][tmpl_df['host sex'].str.startswith('F')] = 'female'
tmpl_df['host sex'][tmpl_df['host sex'].str.startswith('M')] = 'male'
# Out:
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/2388116403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df['host sex'][tmpl_df['host sex'].str.startswith('F')] = 'female'
# /var/folders/78/w3lg7zbx0x1_nfk64y7_350r0000gn/T/ipykernel_16554/2388116403.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpl_df['host sex'][tmpl_df['host sex'].str.startswith('M')] = 'male'

# %%
tmpl_df['geographic location (country and/or sea,region)'] = "USA: California, Davis"
tmpl_df['geographic location (latitude and longitude)'] = tmpl_df['geographic location (latitude and longitude)'].str.replace('∞ N, ', ' -').str.replace('∞ W', '')
tmpl_df['elevation, meters'] = 23.1648
tmpl_df['depth, meters'] = 0.0

# %%
{k: '' for k in set(', '.join(str(s) for s in tmpl_df['chemical administration']).split(', '))}
# Out:
# {'Unasyn': '',
#  'Theophylline': '',
#  'Clindamycin': '',
#  'Maropitant': '',
#  'nan': '',
#  'Cephalexin': '',
#  'Trazadone': '',
#  'Gabapentin': '',
#  'D-penicillamine': '',
#  'Pimobendan': '',
#  'Cyclosporine': '',
#  'Benazapril': '',
#  'Simplicef': '',
#  'Enrofloxacin': '',
#  'Prednisone': '',
#  'Vitamin B12': '',
#  'Prednisolone': '',
#  'Cytopoint': '',
#  'Spironolactone': '',
#  '5-ASA': '',
#  'none': '',
#  'Doxycycline': '',
#  'Denamarin': '',
#  'Pantoprazole': '',
#  'Ondansetron': '',
#  'Carprofen': '',
#  'Omperazole': '',
#  'Metronidazole': '',
#  'Ursodiol': '',
#  'Clavamox': '',
#  'Levetiracetam': ''}

# %%
chemmap = {
 'Pantoprazole': 'CHEBI:50270',
 'Theophylline': 'CHEBI:28177',
 'Ondansetron': 'CHEBI:7773',
 'Clavamox': 'CHEBI:2676',         # check to make sure this is amoxicillan
 'Carprofen': 'CHEBI:364453',
 'Trazadone': 'CHEBI:9654',
 'Spironolactone': 'CHEBI:9241',
 'Levetiracetam': 'CHEBI:6437',
 'Gabapentin': 'CHEBI:42797',
 'Metronidazole': 'CHEBI:6909',
 'Pimobendan': 'CHEBI:32003',
 'Ursodiol': 'CHEBI:9907',
 'Doxycycline': 'CHEBI:50845',
 'Simplicef': 'CHEBI:3504',
 'Unasyn': 'sulbactam [CHEBI:9321]|ampicillin [CHEBI:28971]',
 'Cytopoint': 'cytopoint [CHEBI:00000]',
 'Vitamin B12': 'vitamin B12 [CHEBI:176843]',
 'Cyclosporine': 'CHEBI:4031',
 'Omperazole': 'CHEBI:7772',
 'Prednisolone': 'CHEBI:8378',
 'Maropitant': 'CHEBI:00000',
 'Benazapril': 'CHEBI:3011',
 'D-penicillamine': 'CHEBI:7959',
 'Denamarin': 'S-adenosyl-L-methionine [CHEBI:15414]|silibinin [CHEBI:9144]|phosphatidylcholine [CHEBI:64482]',
 '5-ASA': 'CHEBI:6775',
 'Cephalexin': 'CHEBI:3534',
 'Clindamycin': 'CHEBI:176915',
 'Enrofloxacin': 'CHEBI:35720',
 'Prednisone': 'CHEBI:8382',}

# %%
for k, v in chemmap.items():
    if len(v) == 0:
        print(f"https://duckduckgo.com/?q={k}+chebi&atb=v309-1&ia=web")

# %%
for k in chemmap:
    if '[' not in chemmap[k]:
        chebi = chemmap[k]
        new_k = k[0].lower() + k[1:]
        chemmap[k] = f"{new_k} [{chebi}]"

# %%
chemmap
# Out:
# {'Pantoprazole': 'pantoprazole [CHEBI:50270]',
#  'Theophylline': 'theophylline [CHEBI:28177]',
#  'Ondansetron': 'ondansetron [CHEBI:7773]',
#  'Clavamox': 'clavamox [CHEBI:2676]',
#  'Carprofen': 'carprofen [CHEBI:364453]',
#  'Trazadone': 'trazadone [CHEBI:9654]',
#  'Spironolactone': 'spironolactone [CHEBI:9241]',
#  'Levetiracetam': 'levetiracetam [CHEBI:6437]',
#  'Gabapentin': 'gabapentin [CHEBI:42797]',
#  'Metronidazole': 'metronidazole [CHEBI:6909]',
#  'Pimobendan': 'pimobendan [CHEBI:32003]',
#  'Ursodiol': 'ursodiol [CHEBI:9907]',
#  'Doxycycline': 'doxycycline [CHEBI:50845]',
#  'Simplicef': 'simplicef [CHEBI:3504]',
#  'Unasyn': 'sulbactam [CHEBI:9321]|ampicillin [CHEBI:28971]',
#  'Cytopoint': 'cytopoint [CHEBI:00000]',
#  'Vitamin B12': 'vitamin B12 [CHEBI:176843]',
#  'Cyclosporine': 'cyclosporine [CHEBI:4031]',
#  'Omperazole': 'omperazole [CHEBI:7772]',
#  'Prednisolone': 'prednisolone [CHEBI:8378]',
#  'Maropitant': 'maropitant [CHEBI:00000]',
#  'Benazapril': 'benazapril [CHEBI:3011]',
#  'D-penicillamine': 'd-penicillamine [CHEBI:7959]',
#  'Denamarin': 'S-adenosyl-L-methionine [CHEBI:15414]|silibinin [CHEBI:9144]|phosphatidylcholine [CHEBI:64482]',
#  '5-ASA': '5-ASA [CHEBI:6775]',
#  'Cephalexin': 'cephalexin [CHEBI:3534]',
#  'Clindamycin': 'clindamycin [CHEBI:176915]',
#  'Enrofloxacin': 'enrofloxacin [CHEBI:35720]',
#  'Prednisone': 'prednisone [CHEBI:8382]'}

# %%
new_chem = list()
for v, date in zip(tmpl_df['chemical administration'], tmpl_df['collection date']):
    new_v = list()
    if isinstance(v, float):
        new_chem.append(v)
        continue
    if v == 'none':
        new_chem.append(np.nan)
        continue
    for k in v.split(', '):
        new_v.append(chemmap.get(k, f'{k} [CHEBI:00000]'))
    new_v = '|'.join(new_v).replace(']', f'];{date}')
    print(new_v)
    new_chem.append(new_v)
tmpl_df['chemical administration'] = new_chem
# Out:
# prednisone [CHEBI:8382];2019-09-18|ondansetron [CHEBI:7773];2019-09-18
# prednisone [CHEBI:8382];2019-09-20|ondansetron [CHEBI:7773];2019-09-20|enrofloxacin [CHEBI:35720];2019-09-20
# cytopoint [CHEBI:00000];2019-10-02
# cytopoint [CHEBI:00000];2019-10-22|cephalexin [CHEBI:3534];2019-10-22
# prednisolone [CHEBI:8378];2019-10-07|omperazole [CHEBI:7772];2019-10-07
# prednisolone [CHEBI:8378];2019-10-30|omperazole [CHEBI:7772];2019-10-30|enrofloxacin [CHEBI:35720];2019-10-30|metronidazole [CHEBI:6909];2019-10-30
# cyclosporine [CHEBI:4031];2020-07-06|S-adenosyl-L-methionine [CHEBI:15414];2020-07-06|silibinin [CHEBI:9144];2020-07-06|phosphatidylcholine [CHEBI:64482];2020-07-06|ursodiol [CHEBI:9907];2020-07-06|d-penicillamine [CHEBI:7959];2020-07-06|maropitant [CHEBI:00000];2020-07-06
# cyclosporine [CHEBI:4031];2020-07-13|S-adenosyl-L-methionine [CHEBI:15414];2020-07-13|silibinin [CHEBI:9144];2020-07-13|phosphatidylcholine [CHEBI:64482];2020-07-13|ursodiol [CHEBI:9907];2020-07-13|d-penicillamine [CHEBI:7959];2020-07-13|maropitant [CHEBI:00000];2020-07-13|clavamox [CHEBI:2676];2020-07-13
# prednisone [CHEBI:8382];2020-08-12|ondansetron [CHEBI:7773];2020-08-12
# prednisone [CHEBI:8382];2020-08-18|ondansetron [CHEBI:7773];2020-08-18|clindamycin [CHEBI:176915];2020-08-18
# pimobendan [CHEBI:32003];2021-01-29|benazapril [CHEBI:3011];2021-01-29|spironolactone [CHEBI:9241];2021-01-29|prednisolone [CHEBI:8378];2021-01-29|vitamin B12 [CHEBI:176843];2021-01-29
# pimobendan [CHEBI:32003];2021-02-04|benazapril [CHEBI:3011];2021-02-04|spironolactone [CHEBI:9241];2021-02-04|prednisolone [CHEBI:8378];2021-02-04|vitamin B12 [CHEBI:176843];2021-02-04|clavamox [CHEBI:2676];2021-02-04
# carprofen [CHEBI:364453];2021-02-15
# carprofen [CHEBI:364453];2021-02-20|simplicef [CHEBI:3504];2021-02-20
# carprofen [CHEBI:364453];2021-06-22|trazadone [CHEBI:9654];2021-06-22
# carprofen [CHEBI:364453];2021-06-25|trazadone [CHEBI:9654];2021-06-25|clavamox [CHEBI:2676];2021-06-25
# pantoprazole [CHEBI:50270];2021-06-23|maropitant [CHEBI:00000];2021-06-23
# pantoprazole [CHEBI:50270];2021-06-25|maropitant [CHEBI:00000];2021-06-25|sulbactam [CHEBI:9321];2021-06-25|ampicillin [CHEBI:28971];2021-06-25
# prednisone [CHEBI:8382];2021-07-02|theophylline [CHEBI:28177];2021-07-02
# prednisone [CHEBI:8382];2021-07-08|theophylline [CHEBI:28177];2021-07-08|doxycycline [CHEBI:50845];2021-07-08
# clavamox [CHEBI:2676];2021-09-14
# ursodiol [CHEBI:9907];2021-12-21|S-adenosyl-L-methionine [CHEBI:15414];2021-12-21|silibinin [CHEBI:9144];2021-12-21|phosphatidylcholine [CHEBI:64482];2021-12-21|levetiracetam [CHEBI:6437];2021-12-21|ondansetron [CHEBI:7773];2021-12-21|gabapentin [CHEBI:42797];2021-12-21
# ursodiol [CHEBI:9907];2021-12-24|S-adenosyl-L-methionine [CHEBI:15414];2021-12-24|silibinin [CHEBI:9144];2021-12-24|phosphatidylcholine [CHEBI:64482];2021-12-24|levetiracetam [CHEBI:6437];2021-12-24|ondansetron [CHEBI:7773];2021-12-24|gabapentin [CHEBI:42797];2021-12-24|clavamox [CHEBI:2676];2021-12-24
# clindamycin [CHEBI:176915];2019-10-28
# clindamycin [CHEBI:176915];2021-11-27
# 5-ASA [CHEBI:6775];2021-10-01
# 5-ASA [CHEBI:6775];2021-10-01
# 5-ASA [CHEBI:6775];2021-10-01
# 5-ASA [CHEBI:6775];2021-11-05
# 5-ASA [CHEBI:6775];2021-11-05
# 5-ASA [CHEBI:6775];2021-11-05
# 5-ASA [CHEBI:6775];2021-11-05
# 5-ASA [CHEBI:6775];2021-11-05

# %%
tmpl_df.to_excel('meta_nmdc-44444.xlsx', index=False)
